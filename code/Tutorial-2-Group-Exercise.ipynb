# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
#
# <h2>Data Exploration Group Exercise</h2>
#
# In your group, explore one of the SWDB datasets using the process from the previous tutorial. You'll produce two things:
#
# 1. A **README** for your dataset, following the README template.
# 2. A **summary figure** showing neural activity and behavior timeseries, with stimulus epochs overlaid. Include a figure legend and a claim or observation about the data.
#
# When you're finished, share your README and summary figure to the Slack channel so that others can acccess the information. Each group will then share out their findings and we'll discuss what scientific questions each dataset can address.
#
# </div>

# %% [markdown]
# Starter code and questions to help guide the data exploration process. Along the way, document your findings using the README-template.

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pynwb

data_dir = '/data'

# %%
# Load metadata CSV 

# Uncomment the appropriate metadata csv for your assigned dataset 

# metadata = pd.read_csv('/data/metadata/bci_metadata.csv') # BCI 
# metadata = pd.read_csv('/data/metadata/V1DD_metadata.csv') # V1DD 
# metadata = pd.read_csv('/data/metadata/dynamic_routing_metadata.csv') # Dynamic Foraging 

# metadata

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** What modality was used?
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** How many mice were used in this dataset?
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** How many sessions are in this dataset? How many sessions per mouse?
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** What transgenic lines were used? What cell types do these transgenic lines target?
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** How is the data directory structured? What is file naming scheme?
#
# </div>

# %%
os.listdir(<INSERT DATA PATH HERE>)

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** Open an NWB file. How is the NWB file structured?
#
# </div>

# %%
# Load session data 
nwb_path = ' '

nwb = pynwb.read_nwb(nwb_path)
nwb

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** What units/neurons are available? How many neurons were recorded in this session? Has the data been filtered? What are some relevant details about how the neural activity data is organized and structured.
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** What stimuli, behaviors, and conditions were applied in this session? What is the task structure? How is this information organized?
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** How long is a session?
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** What is the sampling rate?
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** Did the mice receive behavior training before the recording sessions? Are the sessions longitudinal?
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** Plot the neural activity of one or more neurons over the course of the session with the epochs overlaid.
#
# Write a figure caption and a claim or observation about the data.
# </div>

# %% [markdown]
# <div style="background: #FFBF65; border-radius: 3px; padding: 10px;">
#
# **Wrapping up:**
#
# As a group, tidy up your README and figure and post them to the Slack channel.
#
# Try to make sure everything is clear and legible - during the problem set, another group will use your resources to try and recreate your figure!
# </div>
